# %% [markdown]
# # First look at a player's data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
adam = pd.read_csv('/Users/jonsa/OneDrive/Documents/code/players/adam svensson.csv').drop('Unnamed: 0', axis =1)
print(adam.head())
# Out:
#    hole  score  round  par  yards  average_score  location        date  temp  \
# 0   1.0    3.0    1.0    4    439          3.907  Napa, CA  2021-09-16    69
# 1   2.0    2.0    1.0    3    186          3.197  Napa, CA  2021-09-16    69
# 2   3.0    4.0    1.0    4    433          3.991  Napa, CA  2021-09-16    69
# 3   4.0    4.0    1.0    4    409          4.135  Napa, CA  2021-09-16    69
# 4   5.0    4.0    1.0    5    537          4.573  Napa, CA  2021-09-16    69
#
#    wind  rain
# 0    12   0.0
# 1    12   0.0
# 2    12   0.0
# 3    12   0.0
# 4    12   0.0

# %%
adam.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108 entries, 0 to 107
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   hole           108 non-null    float64
#  1   score          108 non-null    float64
#  2   round          108 non-null    float64
#  3   par            108 non-null    int64
#  4   yards          108 non-null    int64
#  5   average_score  108 non-null    float64
#  6   location       108 non-null    object
#  7   date           108 non-null    object
#  8   temp           108 non-null    int64
#  9   wind           108 non-null    int64
#  10  rain           108 non-null    float64
# dtypes: float64(5), int64(4), object(2)
# memory usage: 9.4+ KB

# %%
adam.describe()
# Out:
#              hole       score       round         par       yards  \
# count  108.000000  108.000000  108.000000  108.000000  108.000000
# mean     9.500000    3.953704    2.166667    4.000000  396.666667
# std      5.212315    0.879510    1.072163    0.669775  132.431749
# min      1.000000    2.000000    1.000000    3.000000  152.000000
# 25%      5.000000    3.000000    1.000000    4.000000  348.000000
# 50%      9.500000    4.000000    2.000000    4.000000  419.000000
# 75%     14.000000    5.000000    3.000000    4.000000  483.000000
# max     18.000000    6.000000    4.000000    5.000000  604.000000
#
#        average_score        temp        wind        rain
# count     108.000000  108.000000  108.000000  108.000000
# mean        3.925241   76.000000   11.166667    0.033333
# std         0.539916    7.337014    1.682788    0.047360
# min         2.835000   65.000000    8.000000    0.000000
# 25%         3.816000   69.000000   10.000000    0.000000
# ...

# %%
sns.histplot(adam['score'], kde = False)
# Out:
# <AxesSubplot: xlabel='score', ylabel='Count'>

# %%
sns.pairplot(adam)
